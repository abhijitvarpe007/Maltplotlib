# %% [markdown]
# ### How to show image using matplotlib imshow function

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
img=mpimg.imread("pie_chart.png")

# %%
img
# Out:
# array([[[0.       , 0.5019608, 0.       , 1.       ],
#         [0.       , 0.5019608, 0.       , 1.       ],
#         [0.       , 0.5019608, 0.       , 1.       ],
#         ...,
#         [0.       , 0.5019608, 0.       , 1.       ],
#         [0.       , 0.5019608, 0.       , 1.       ],
#         [0.       , 0.5019608, 0.       , 1.       ]],
#
#        [[0.       , 0.5019608, 0.       , 1.       ],
#         [0.       , 0.5019608, 0.       , 1.       ],
#         [0.       , 0.5019608, 0.       , 1.       ],
#         ...,
#         [0.       , 0.5019608, 0.       , 1.       ],
#         [0.       , 0.5019608, 0.       , 1.       ],
#         [0.       , 0.5019608, 0.       , 1.       ]],
#
#        [[0.       , 0.5019608, 0.       , 1.       ],
#         [0.       , 0.5019608, 0.       , 1.       ],
#         [0.       , 0.5019608, 0.       , 1.       ],
#         ...,
#         [0.       , 0.5019608, 0.       , 1.       ],
# ...

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (400, 600, 4)

# %%
img.ndim
# Out:
# 3

# %%
plt.imshow(img)
plt.show()

# %%
plt.figure(figsize=(12,7))
plt.axis('off')
plt.imshow(img)
plt.show()

# %%
plt.figure(figsize=(12,7))
plt.axis('off')
plt.imshow(img)
plt.colorbar()
plt.show()

# %%
img1=img[:,:,1]
plt.figure(figsize=(12,7))
plt.axis('off')
plt.imshow(img1,cmap='hot')
plt.colorbar()
plt.show()

# %%
img2=mpimg.imread('C:\\Users\\HP\\OpenCv\\tiger.png')
plt.figure(figsize=(12,7))
plt.axis('off')
plt.imshow(img2)
plt.colorbar()
plt.show()

# %%
single_img=img2[:,:,1]
plt.figure(figsize=(12,7))
plt.axis('off')
plt.imshow(single_img,cmap='hot')
plt.colorbar()
plt.savefig('model_hot.png')
plt.show()

# %%
single_img=img2[:,:,1]
plt.figure(figsize=(12,7))
plt.axis('off')
plt.imshow(single_img,cmap='nipy_spectral')
plt.colorbar()

plt.show()
